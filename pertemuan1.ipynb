# %% [markdown]
# # Pertemuan 1 – Pengenalan Kecerdasan Komputasional
#
# ## Tujuan
# - Memahami konsep AI
# - Mengenal machine learning
#
# ## Teori Singkat
# Kecerdasan komputasional adalah bidang ilmu yang mempelajari
# cara komputer meniru kecerdasan manusia.
#
# ## Kesimpulan
# Materi membahas konsep dasar AI.

# %%
print("hello world")
# Out:
# hello world
